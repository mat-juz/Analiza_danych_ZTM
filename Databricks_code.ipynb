# %%
from kafka import KafkaProducer, KafkaConsumer
import time
import json
from pyspark.sql import *
from pyspark.sql.types import *
from pyspark.sql.functions import *
import requests
import geopandas as gpd
from shapely.geometry import Point
from shapely.geometry import Polygon
import pandas as pd

# %% [markdown]
# #### Kafka consumer do pobierania danych strumieniowych z API ZTM

# %%
d = spark\
  .readStream\
  .format("kafka")\
  .option("kafka.bootstrap.servers", "ec2-35-158-128-12.eu-central-1.compute.amazonaws.com:9092")\
  .option("subscribe", "BUS__221")\
  .load()

# %% [markdown]
# ##### Przygotowanie danych

# %%
d2 = d.select(d.value.cast(StringType()))

# %%
split_col = split(d2['value'],',')

# %%
d2 = d2.withColumn("Lines", translate(split_col.getItem(0),'[',''))
d2 = d2.withColumn("Line", translate("Lines",'"',''))
d2 = d2.withColumn("Lon", split_col.getItem(1))
d2 = d2.withColumn("VehicleNumber", translate(split_col.getItem(2),'"',''))
d2 = d2.withColumn("Time", translate(split_col.getItem(3),'"','').cast("timestamp"))
d2 = d2.withColumn("Lat", split_col.getItem(4))
d2 = d2.withColumn("Brigade", translate(split_col.getItem(5),'"',''))
d2 = d2.withColumn("BrigadeID", translate("Brigade",']',''))

# %%
d3 = d2.select(d2['Line'],d2['VehicleNumber'],d2['Time'],d2['BrigadeID'],d2['Lat'],d2['Lon'])
d3 = d3.withColumn('date', to_date(col('Time'),'yyyy-MM-dd'))
d3 = d3.withColumn('time', date_format(col('Time'),'HH:mm:ss'))

# %%
d4 = d3.select(d3['Line'],d3['VehicleNumber'],d3['BrigadeID'],d3['Lat'],d3['Lon'],d3['date'],d3['time'])

# %% [markdown]
# ##### Wyświetlenie danych na mapie

# %%
display(d4)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Line</th><th>VehicleNumber</th><th>BrigadeID</th><th>Lat</th><th>Lon</th><th>date</th><th>time</th></tr></thead><tbody><tr><td>221</td><td> 9221</td><td> 1</td><td> 52.2593973</td><td> 20.9802829</td><td>2023-02-05</td><td>12:05:19</td></tr><tr><td>221</td><td> 9229</td><td> 2</td><td> 52.2594626</td><td> 20.994034</td><td>2023-02-05</td><td>12:05:25</td></tr><tr><td>221</td><td> 9221</td><td> 1</td><td> 52.2598356</td><td> 20.98192</td><td>2023-02-05</td><td>12:05:37</td></tr><tr><td>221</td><td> 9229</td><td> 2</td><td> 52.2594568</td><td> 20.9940376</td><td>2023-02-05</td><td>12:05:36</td></tr><tr><td>221</td><td> 9221</td><td> 1</td><td> 52.2599156</td><td> 20.982681</td><td>2023-02-05</td><td>12:05:47</td></tr><tr><td>221</td><td> 9229</td><td> 2</td><td> 52.2594426</td><td> 20.9940438</td><td>2023-02-05</td><td>12:05:48</td></tr><tr><td>221</td><td> 9221</td><td> 1</td><td> 52.2599993</td><td> 20.9832218</td><td>2023-02-05</td><td>12:05:58</td></tr><tr><td>221</td><td> 9229</td><td> 2</td><td> 52.2594376</td><td> 20.9940355</td><td>2023-02-05</td><td>12:05:58</td></tr><tr><td>221</td><td> 9221</td><td> 1</td><td> 52.2602107</td><
td><td>20.983128</td><td>6198</td><td>01</td><td>ks.Boguckiego</td><td>Felińskiego</td></tr><tr><td>6344</td><td>52.260057</td><td>20.984033</td><td>6198</td><td>02</td><td>ks.Boguckiego</td><td>pl.Grunwaldzki</td></tr><tr><td>6358</td><td>52.259463</td><td>20.993562</td><td>6212</td><td>01</td><td>Dw.Gdański (Rydygiera)</td><td>______________________________</td></tr><tr><td>6359</td><td>52.259515</td><td>20.992735</td><td>6212</td><td>02</td><td>Dw.Gdański (Rydygiera)</td><td>Felińskiego</td></tr><tr><td>6360</td><td>52.259452</td><td>20.993967</td><td>6212</td><td>71</td><td>Dw.Gdański (Rydygiera)</td><td>______________________________</td></tr><tr><td>6363</td><td>52.259830</td><td>20.975171</td><td>6215</td><td>01</td><td>Anny German</td><td>pl.Grunwaldzki</td></tr><tr><td>6364</td><td>52.259397</td><td>20.973681</td><td>6215</td><td>02</td><td>Anny German</td><td>Przasnyska</td></tr><tr><td>6368</td><td>52.257063</td><td>20.966799</td><td>6221</td><td>02</td><td>pl.Niemena</td><td>Krasińskiego</td></tr></tbody></table></div>

# %% [markdown]
# ##### Transformacja do formatu pandas

# %%
stops_221 = point_csv_df.toPandas()

# %% [markdown]
# ##### Utworzenie Geo Data Frame

# %%
gdf = gpd.GeoDataFrame(
    stops_221, geometry=gpd.points_from_xy(stops_221.DLUG_GEO, stops_221.SZER_GEO),crs="EPSG:4326")

# %% [markdown]
# ##### Stworzenie bufora dookoła każdego z przystanków

# %%
gdf.to_crs("EPSG:3857")
gdf['geometry']=gdf.geometry.buffer(0.0002)
gdf.to_crs("EPSG:4326")
# Out:
# <command-3490990717133163>:2: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf['geometry']=gdf.geometry.buffer(0.0002)
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>_c0</th>
#       <th>SZER_GEO</th>
#       <th>DLUG_GEO</th>
#       <th>Zespol</th>
#       <th>Slupek</th>
#       <th>Nazwa_zespolu</th>
#       <th>KIERUNEK</th>
#       <th>geometry</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>5964</td>
#       <td>52.263658</td>
#       <td>20.978727</td>
#       <td>6039</td>
#       <td>01</td>
#       <td>pl.Grunwaldzki</td>
#       <td>"rondo ""Radosława"""</td>
#       <td>POLYGON ((20.97893 52.26366, 20.97893 52.26364...</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>5965</td>
#       <td>52.262923</td>
#       <td>20.979629</td>
#       <td>6039</td>
#       <td>02</td>
#       <td>pl.Grunwaldzki</td>
#       <td>Krasińskiego</td>
#       <td>POLYGON ((20.97983 52.26292, 20.97983 52.26290...</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>5966</td>
#       <td>52.262850</td>
#       <td>20.979453</td>
#       <td>6039</td>
#       <td>03</td>
#       <td>pl.Grunwaldzki</td>
#       <td>"rondo ""Radosława"""</td>
#       <td>POLYGON ((20.97965 52.26285, 20.97965 52.26283...</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>5967</td>
#       <td>52.263328</td>
#       <td>20.979185</td>
#       <td>6039</td>
#       <td>04</td>
#       <td>pl.Grunwaldzki</td>
#       <td>Metro Marymont</td>
#       <td>POLYGON ((20.97939 52.26333, 20.97938 52.26331...</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>
td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>6358</td>
#       <td>52.259463</td>
#       <td>20.993562</td>
#       <td>6212</td>
#       <td>01</td>
#       <td>Dw.Gdański (Rydygiera)</td>
#       <td>______________________________</td>
#       <td>POLYGON ((20.99376 52.25946, 20.99376 52.25944...</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>6359</td>
#       <td>52.259515</td>
#       <td>20.992735</td>
#       <td>6212</td>
#       <td>02</td>
#       <td>Dw.Gdański (Rydygiera)</td>
#       <td>Felińskiego</td>
#       <td>POLYGON ((20.99293 52.25952, 20.99293 52.25950...</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>6360</td>
#       <td>52.259452</td>
#       <td>20.993967</td>
#       <td>6212</td>
#       <td>71</td>
#       <td>Dw.Gdański (Rydygiera)</td>
#       <td>______________________________</td>
#       <td>POLYGON ((20.99417 52.25945, 20.99417 52.25943...</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>6363</td>
#       <td>52.259830</td>
#       <td>20.975171</td>
#       <td>6215</td>
#       <td>01</td>
#       <td>Anny German</td>
#       <td>pl.Grunwaldzki</td>
#       <td>POLYGON ((20.97537 52.25983, 20.97537 52.25981...</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>6364</td>
#       <td>52.259397</td>
#       <td>20.973681</td>
#       <td>6215</td>
#       <td>02</td>
#       <td>Anny German</td>
#       <td>Przasnyska</td>
#       <td>POLYGON ((20.97388 52.25940, 20.97388 52.25938...</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>6368</td>
#       <td>52.257063</td>
#       <td>20.966799</td>
#       <td>6221</td>
#       <td>02</td>
#       <td>pl.Niemena</td>
#       <td>Krasińskiego</td>
#       <td>POLYGON ((20.96700 52.25706, 20.96700 52.25704...</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ##### Wyświetlenie danych na mapie

# %%
from matplotlib import *
from mapclassify import *
from folium import *

# %%
gdf.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e497d3c70fecfbd3cffdbf8060467503 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e497d3c70fecfbd3cffdbf8060467503&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e497d3c70fecfbd3cffdbf8060467503 = L.map(
#                 &quot;map_e497d3c70fecfbd3cffdbf8060467503&quot;,
#                 {
#                     center: [52.259806, 20.980383000000003],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_e497d3c70fecfbd3cffdbf8060467503);
#
#
#
#
#
#             var tile_layer_7c37ca21341f2b240b9bd5dff29811a8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e497d3c70fecfbd3cffdbf8060467503);
#
#
#             map_e497d3c70fecfbd3cffdbf8060467503.fitBounds(
#                 [[52.255754, 20.966599000000002], [52.263858, 20.994167]],
#                 {}
#             );
#
#
#         function geo_json_92b823178428075f66bdad58b0503384_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_92b823178428075f66bdad58b0503384_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_92b823178428075f66bdad58b0503384_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_92b823178428075f66bdad58b0503384_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_92b823178428075f66bdad58b0503384_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_92b823178428075f66bdad58b0503384.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_92b823178428075f66bdad58b0503384_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_92b823178428075f66bdad58b0503384 = L.geoJson(null, {
#                 onEachFeature: geo_json_92b823178428075f66bdad58b0503384_onEachFeature,
#
#                 style: geo_json_92b823178428075f66bdad58b0503384_styler,
#                 pointToLayer: geo_json_92b823178428075f66bdad58b0503384_pointToLayer
#         });
#
#         function geo_json_92b823178428075f66bdad58b0503384_add (data) {
#             geo_json_92b823178428075f66bdad58b0503384
#                 .addData(data)
#                 .addTo(map_e497d3c70fecfbd3cffdbf8060467503);
#         }
#             geo_json_92b823178428075f66bdad58b0503384_add({&quot;bbox&quot;: [20.966599000000002, 52.255754, 20.994167, 52.263858], &quot;features&quot;: [{&quot;bbox&quot;: [20.978527, 52.263458, 20.978927, 52.263858], &quot;geometry&quot;: {&quot;coordinates&quot;: [[
td></tr><tr><td>221</td><td>9225</td><td>2</td><td>52.2594175</td><td>20.9941275</td><td>2023-01-28</td><td>10:38:39</td><td>27</td></tr><tr><td>221</td><td>9218</td><td>1</td><td>52.257599</td><td>20.968767</td><td>2023-01-28</td><td>10:38:45</td><td>28</td></tr><tr><td>221</td><td>9225</td><td>2</td><td>52.2594 ...

# %%
gdf_bus = gpd.GeoDataFrame(
    bus_221_p, geometry=gpd.points_from_xy(bus_221_p.Lon, bus_221_p.Lat),crs="EPSG:4326")

# %% [markdown]
# ##### Wyswietlenie danych punktowych i bufora na mapie

# %%
m = gdf.explore(height=250, width=500, name="Polygons")
m = gdf_bus.explore(m=m, color="red", name="Points")
LayerControl().add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5ef6d99057102fdf71f080d9588d24cc {
#                     position: relative;
#                     width: 500.0px;
#                     height: 250.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5ef6d99057102fdf71f080d9588d24cc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5ef6d99057102fdf71f080d9588d24cc = L.map(
#                 &quot;map_5ef6d99057102fdf71f080d9588d24cc&quot;,
#                 {
#                     center: [52.259806, 20.980383000000003],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_5ef6d99057102fdf71f080d9588d24cc);
#
#
#
#
#
#             var tile_layer_787c01b34c02cf77b6b6f0b7e8c6ce04 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5ef6d99057102fdf71f080d9588d24cc);
#
#
#             map_5ef6d99057102fdf71f080d9588d24cc.fitBounds(
#                 [[52.255754, 20.966599000000002], [52.263858, 20.994167]],
#                 {}
#             );
#
#
#         function geo_json_b8e47af6a50bd0c86362e0653a026f9f_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_b8e47af6a50bd0c86362e0653a026f9f_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_b8e47af6a50bd0c86362e0653a026f9f_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_b8e47af6a50bd0c86362e0653a026f9f_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_b8e47af6a50bd0c86362e0653a026f9f_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_b8e47af6a50bd0c86362e0653a026f9f.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_b8e47af6a50bd0c86362e0653a026f9f_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_b8e47af6a50bd0c86362e0653a026f9f = L.geoJson(null, {
#                 onEachFeature: geo_json_b8e47af6a50bd0c86362e0653a026f9f_onEachFeature,
#
#                 style: geo_json_b8e47af6a50bd0c86362e0653a026f9f_styler,
#                 pointToLayer: geo_json_b8e47af6a50bd0c86362e0653a026f9f_pointToLayer
#         });
#
#         function geo_json_b8e47af6a50bd0c86362e0653a026f9f_add (data) {
#             geo_json_b8e47af6a50bd0c86362e0653a026f9f
#                 .addData(data)
#                 .addTo(map_5ef6d99057102fdf71f080d9588d24cc);
#         }
#             geo_json_b8e47af6a50bd0c86362e0653a026f9f_add({&quot;bbox&quot;: [20.966599000000002, 52.255754, 20.994167, 52.263858], &quot;features&quot;: [{&quot;bbox&quot;: [20.978527, 5

# %% [markdown]
# ##### Sprawdzenie czy autobus znajduje sie w buforze sprzystanku

# %%
df = pd.DataFrame(columns=['ID_BUS','Zespol','Slupek','Wewn'])
for row in gdf.itertuples():
    for bus in gdf_bus.itertuples():
        list1 = [bus.ID, row.Zespol, row.Slupek, bus.geometry.within(row.geometry)]
        df.loc[len(df)] = list1
print(df)
# Out:
#              ID_BUS Zespol Slupek   Wewn
# 0                 0   6039     01  False
# 1                 1   6039     01  False
# 2                 2   6039     01  False
# 3                 3   6039     01  False
# 4                 4   6039     01  False
# ...             ...    ...    ...    ...
# 16737  111669149711   6221     02  False
# 16738  111669149712   6221     02  False
# 16739  111669149713   6221     02  False
# 16740  111669149714   6221     02  False
# 16741  111669149715   6221     02  False
#
# [16742 rows x 4 columns]

# %% [markdown]
# ##### Wybranie tylko rekordów, które znajdują się w buforze w celu analizy opóźnień

# %%
true_df = df[df['Wewn']==True]
print(true_df)
# Out:
#              ID_BUS Zespol Slupek  Wewn
# 4769    25769803787   6039     13  True
# 4867    34359738413   6039     13  True
# 5115    68719476773   6039     13  True
# 5213    85899345927   6039     13  True
# 5534    25769803791   6039     14  True
# ...             ...    ...    ...   ...
# 16448   60129542163   6221     02  True
# 16641   85899345940   6221     02  True
# 16666   94489280520   6221     02  True
# 16689   94489280543   6221     02  True
# 16718  103079215132   6221     02  True
#
# [534 rows x 4 columns]

# %%
S_DF = spark.createDataFrame(true_df)

# %% [markdown]
# ##### Wczytanie danych o rozkładzie jazdy

# %%
timetable_221_df = spark.read.format("csv").\
    option("delimiter", ",").\
    option("header", "true").\
    load("dbfs:/FileStore/tables/timetable_221.csv")

# %% [markdown]
# ##### Połączenie tabel

# %%
join_1 = S_DF.join(bus_221, S_DF.ID_BUS == bus_221.ID,"left").drop(S_DF.ID_BUS)

# %% [markdown]
# ##### Przygotowanie danych dotyczących rozkładu jazdu

# %%
timetable_221_df = timetable_221_df.withColumn('time_timetable', date_format(col('czas'),'HH:mm:ss'))

# %% [markdown]
# ##### Dodanie kolumn +/-20 min od czasu odjazdu

# %%
timetable_221_df = timetable_221_df.withColumn('start_timetable',timetable_221_df.czas - expr('INTERVAL 20 MINUTES'))
timetable_221_df = timetable_221_df.withColumn('end_timetable',timetable_221_df.czas + expr('INTERVAL 20 MINUTES'))
timetable_221_df = timetable_221_df.withColumn('start_timetable', date_format(col('start_timetable'),'HH:mm:ss'))
timetable_221_df = timetable_221_df.withColumn('end_timetable', date_format(col('end_timetable'),'HH:mm:ss'))

# %%
timetable_221_df  = timetable_221_df.drop(timetable_221_df.Symbol_1)
timetable_221_df  = timetable_221_df.drop(timetable_221_df.Symbol_2
display(timetable_221_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_c0</th><th>Line</th><th>zespol</th><th>Slupek</th><th>Brygada</th><th>kierunek</th><th>trasa</th><th>time_timetable</th><th>start_timetable</th><th>end_timetable</th></tr></thead><tbody><tr><td>0</td><td>221</td><td>6039</td><td>13</td><td>1</td><td>Dw.Gdański (Rydygiera)</td><td>TP-DWR</td><td>05:05:00</td><td>04:45:00</td><td>05:25:00</td></tr><tr><td>1</td><td>221</td><td>6039</td><td>13</td><td>1</td><td>Dw.Gdański (Rydygiera)</td><td>TP-DWR</td><td>05:35:00</td><td>05:15:00</td><td>05:55:00</td></tr><tr><td>2</td><td>221</td><td>6039</td><td>13</td><td>1</td><td>Dw.Gdański (Rydygiera)</td><td>TP-DWR</td><td>06:05:00</td><td>05:45:00</td><td>06:25:00</td></tr><tr><td>3</td><td>221</td><td>6039</td><td>13</td><td>1</td><td>Dw.Gdański (Rydygiera)</td><td>TP-DWR</td><td>06:25:00</td><td>06:05:00</td><td>06:45:00</td></tr><tr><td>4</td><td>221</td><td>6039</td><td>13</td><td>1</td><td>Dw.Gdański (Rydygiera)</td><td>TP-DWR</td><td
td><td>9225</td><td>2</td><td>2023-01-28</td><td>12:23:45</td><td>12:23:00</td></tr><tr><td>6089</td><td>Rydygiera</td><td>04</td><td>pl.Niemena</td><td>9225</td><td>2</td><td>2023-01-28</td><td>11:38:36</td><td>11:39:00</td></tr><tr><td>6089</td><td>Rydygiera</td><td>04</td><td>pl.Niemena</td><td>9225</td><td>2</td><td>2023-01-28</td><td>11:38:32</td><td>11:39:00</td></tr><tr><td>6197</td><td>Felińskiego</td><td>01</td><td>Dw.Gdański (Rydygiera)</td><td>9218</td><td>1</td><td>2023-01-28</td><td>12:07:30</td><td>12:07:00</td></tr><tr><td>6197</td><td>Felińskiego</td><td>01</td><td>Dw.Gdański (Rydygiera)</td><td>9218</td><td>1</td><td>2023-01-28</td><td>10:47:14</td><td>10:47:00</td></tr><tr><td>6197</td><td>Felińskiego</td><td>01</td><td>Dw.Gdański (Rydygiera)</td><td>9218</td><td>1</td><td>2023-01-28</td><td>11:27:36</td><td>11:27:00</td></tr><tr><td>6197</td><td>Felińskiego</td><td>01</td><td>Dw.Gdański (Rydygiera)</td><td>9225</td><td>2</td><td>2023-01-28</td><td>12:14:22</td><td>12:27:00</td></tr><tr><td>6197</td><td>Felińskiego</td><td>01</td><td>Dw.Gdański (Rydygiera)</td><td>9225</td><td>2</td><td>2023-01-28</td><td>12:28:28</td><td>12:27:00</td></tr><tr><td>6197</td><td>Felińskiego</td><td>01</td><td>Dw.Gdański (Rydygiera)</td><td>9225</td><td>2</td><td>2023-01-28</td><td>12:28:39</td><td>12:27:00</td></tr><tr><td>6197</td><td>Felińskiego</td><td>01</td><td>Dw.Gdański (Rydygiera)</td><td>9218</td><td>1</t ...

# %% [markdown]
# ##### Obliczenie opóźnienia

# %%
from pyspark.sql import functions as F
timeFmt = "HH:mm:ss"
timeDiff = round(((F.unix_timestamp('time', format=timeFmt)
            - F.unix_timestamp('time_timetable', format=timeFmt))/60),0)
df_summary = df_summary.withColumn("delay", timeDiff)

# %% [markdown]
# ##### Wiświetlenie danych od najnowszych

# %%
df_summary = df_summary.distinct()
display(df_summary.sort(df_summary.time.desc()))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Zespol</th><th>Nazwa_zespolu</th><th>Slupek</th><th>kierunek</th><th>VehicleNumber</th><th>BrigadeID</th><th>date</th><th>time</th><th>time_timetable</th><th>delay</th></tr></thead><tbody><tr><td>6212</td><td>Dw.Gdański (Rydygiera)</td><td>71</td><td>pl.Niemena</td><td>9225</td><td>2</td><td>2023-01-28</td><td>12:37:42</td><td>12:52:00</td><td>-14.0</td></tr><tr><td>6215</td><td>Anny German</td><td>02</td><td>pl.Niemena</td><td>9218</td><td>1</td><td>2023-01-28</td><td>12:37:39</td><td>12:38:00</td><td>0.0</td></tr><tr><td>6212</td><td>Dw.Gdański (Rydygiera)</td><td>71</td><td>pl.Niemena</td><td>9225</td><td>2</td><td>2023-01-28</td><td>12:37:25</td><td>12:52:00</td><td>-15.0</td></tr><tr><td>6212</td><td>Dw.Gdański (Rydygiera)</td><td>71</td><td>pl.Niemena</td><td>9225</td><td>2</td><td>2023-01-28</td><td>12:32:14</td><td>12:52:00</td><td>-20.0</td></tr><tr><td>6212</td><td>Dw.Gdański (Rydygiera)</td><td>71</td><td>pl.Niemena</td><td>9218</td><td>1</td><td>2023-01-28</td><td>12:32:11</td><td>12:32:00</td><td>0.0</td></tr><tr><td>6212</td><td>Dw.Gdański (Rydygiera)</td><td>71</td><td>pl.Niemena</td><td>9225</td><td>2</td><td>2023-01-28</td><td>12